# %% [markdown]
# <a href="https://colab.research.google.com/github/ayami-n/X-ray-YOLO/blob/main/Slim_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/YOLO_Custom
# Out:
# /content/gdrive/MyDrive/YOLO_Custom

# %% [markdown]
# Create Data Folder at YOLO_Custom

# %%
# %mkdir data # if tain.txt has Data/obj/****.jpg, thne folder name is Data

# %% [markdown]
# Make Sure Files Folder contains [ _darknet.txt, train.txt, and valid.txt [link text ]

# %%
# %cp Files/_darknet.txt Train/_darknet.labels
# %cp Files/train.txt data/train.txt
# %cp Files/vaild.txt data/valid.txt

# %%
# %cp Files1/_darknet.txt Train1/_darknet.labels
# %cp Files1/train.txt data1/train.txt
# %cp Files1/vaild.txt data1/valid.txt

# %% [markdown]
# The below step takes a lot of time

# %%
# %cp Train/_darknet.labels data/obj.names # create files for learning, make sure correct location and create data folder for each custome detection
# %mkdir data/obj # if data folder is not empty, make new data1, data2 and so on and change the folder names

# %cp Train/*.jpg data/obj/
# %cp Valid/*.jpg data/obj/

# %cp Train/*.txt data/obj/
# %cp Valid/*.txt data/obj/

with open('data/obj.data', 'w') as out:
  out.write('classes = 4\n')
  out.write('train = data/train.txt\n')
  out.write('valid = data/valid.txt\n')
  out.write('names = data/obj.names\n')
  out.write('backup = backup/')

# %%
# %cp Train1/_darknet.labels data1/obj.names # create files for learning, make sure correct location and create data folder for each custome detection
# %mkdir data1/obj # if data folder is not empty, make new data1, data2 and so on and change the folder names

# %cp Train1/*.jpg data1/obj/
# %cp Valid1/*.jpg data1/obj/

# %cp Train1/*.txt data1/obj/
# %cp Valid1/*.txt data1/obj/

with open('data1/obj.data', 'w') as out:
  out.write('classes = 4\n')
  out.write('train = data1/train.txt\n')
  out.write('valid = data1/valid.txt\n')
  out.write('names = data1/obj.names\n')
  out.write('backup = backup1/')
# Out:
# mkdir: cannot create directory ‘data1/obj’: File exists

# %% [markdown]
# Giving the permission to access darknet from /content/gdrive/MyDrive/YOLO_Custom If permission error occurs

# %%
# !chmod +x darknet/darknet # if the location is different try !chmod +x ./darknet

# %% [markdown]
# Check lists:
# *  Did you create/modify a cfg file?
# *  Are the images size divided by 32? (256,416,512,1280)
# *  Do you have all items in the Data folder?
# *  Did you compile YOLO %make if you installed YOLO as the first time?
# *  Do you have a backup folder?
# *  Is the labels folder in the Data foler?

# %% [markdown]
# ### Training: GPU MUST BE ON

# %%
# !darknet/darknet detector train data1/obj.data darknet/cfg/yolov4-custom1.cfg darknet/custom_weight/yolov4.conv.137 -dont_show #train data/data.data
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 1485174, rewritten_bbox = 0.111771 %
#
#  2046: 5.690588, 4.179756 avg loss, 0.001000 rate, 4.058633 seconds, 130944 images, 10.904292 hours left
# Loaded: 0.000064 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.827201), count: 1, class_loss = 0.368550, iou_loss = 0.692113, total_loss = 1.060664
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.735167), count: 11, class_loss = 2.905125, iou_loss = 1.708177, total_loss = 4.613302
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.728387), count: 10, class_loss = 2.370480, iou_loss = 0.379996, total_loss = 2.750476
#  total_bbox = 1485196, rewritten_bbox = 0.111770 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000009, iou_loss = 0.000000, total_loss = 0.000009
# ...

# %% [markdown]
# For testing, must change the batch and subdivisons

# %%
# !sed -i 's/batch=64/batch=1/' cfg/yolov4_custom1.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' cfg/yolov4_custom1.cfg

# %% [markdown]
# Evaluation

# %%
#define utility function
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# %cd /content/gdrive/MyDrive/YOLO_Custom

# %% [markdown]
# Check Weight

# %%
# !ls backup

# %%
#/test has images that we can test our detector on
import os
test_images = [f for f in os.listdir('Test') if f.endswith('.jpg')]
import random
img_path = "Test/" + random.choice(test_images);

#test out our detector!
# !darknet/darknet detector test data/obj.data darknet/cfg/yolov4_custom.cfg backup/yolov4_custom_last.weights {img_path} -dont-show
imShow('/content/gdrive/MyDrive/YOLO_Custom/predictions.jpg')
